# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\rudra\Downloads\webtraffic.csv")

# %%
data.shape
# Out:
# (4896, 2)

# %%
data.head()
# Out:
#    Hour Index    Sessions
# 0           0  1418159421
# 1           1  1113769116
# 2           2   919158921
# 3           3   822352824
# 4           4   735526737

# %%
import matplotlib.pyplot as plt
sessions = data['Sessions'].values

# %%
ar = np.arange(len(sessions))
plt.figure(figsize=(22,10))
plt.plot(ar, sessions,'r')
plt.show()

# %%
#Let’s explore this data, at a more granular level, and replacing the entire time series, with a subset of it.

#first week web traffic
sample = sessions[:168]
ar = np.arange(len(sample))
plt.figure(figsize=(22,10))
plt.plot(ar, sample,'r')
plt.show()

# %%
#let’s prepare the data for model training, here I have created input sequences, from the block traffic data.

def prepare_data(seq,num):
  x=[]
  y=[]
  for i in range(0,(len(seq)-num),1):
    
    input_ = seq[i:i+num]
    output  = seq[i+num]
    
    x.append(input_)
    y.append(output)
    
  return np.array(x), np.array(y)

# %%
#I have specified the sequence length of one week or 168 hours

num=168
x,y= prepare_data(sessions,num)
print(len(x))
# Out:
# 4728

# %%
#Next, I have split the data into a training set and validation set in the ratio, 90 is to 10. Now that sense it is a time serious problem, I have not splitted the data randomly, but in a sequential manner.

ind = int(0.9 * len(x))
x_tr = x[:ind]
y_tr = y[:ind]
x_val=x[ind:]
y_val=y[ind:]

# %%
#I have scaled the data, both the input sequences and the target values, are scaled

from sklearn.preprocessing import StandardScaler
#normalizing the inputs
x_scaler= StandardScaler()
x_tr = x_scaler.fit_transform(x_tr)
x_val= x_scaler.transform(x_val)

# %%
#reshaping the output for normalization
y_tr=y_tr.reshape(len(y_tr),1)
y_val=y_val.reshape(len(y_val),1)

# %%
#normalizing the output
y_scaler=StandardScaler()
y_tr = y_scaler.fit_transform(y_tr)[:,0]
y_val = y_scaler.transform(y_val)[:,0]

# %%
#I have reshaped the data from two dimensional to 3 dimensional because LSTM only accepts 3 dimensional data.

#reshaping input data
x_tr= x_tr.reshape(x_tr.shape[0],x_tr.shape[1],1)
x_val= x_val.reshape(x_val.shape[0],x_val.shape[1],1)
print(x_tr.shape)
# Out:
# (4255, 168, 1)

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\rudra\anaconda3\lib\site-packages (2.13.0)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\rudra\anaconda3\lib\site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\rudra\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\rudra\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\rudra\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\rudra\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\rudra\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\rudra\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.7.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\rudra\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (16.0.6)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in c:\users\rudra\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\rudra\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\rudra\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (23.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\rudra\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.24.0)
# Requirement already satisfied: setuptools in c:\users\rudra\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (67.8.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\rudra\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\rudra\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\rudra\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\rudra\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\rudra\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.56.2)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\rudra\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\rudra\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\rudra\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\rudra\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\rudra\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\rudra\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.22.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\rudra\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\rudra\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\rudra\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.29.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\rudra\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\rudra\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\rudra\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\rudra\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\rudra\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (4.9)
# Requirement already satisfied: urllib3<2.0 in c:\users\rudra\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\rudra\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rudra\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rudra\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rudra\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\rudra\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\rudra\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\rudra\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from keras.models import *
from keras.layers import *
from keras.callbacks import *
from tensorflow import keras

# %%
# define model
model =  Sequential()
model.add(LSTM(128,input_shape=(168,1)))
model.add(Dense(64,activation='relu'))
model.add(Dense(1,activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 128)               66560
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dense_9 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 74881 (292.50 KB)
# Trainable params: 74881 (292.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Define the optimizer and loss
model.compile(loss='mse',optimizer='adam')

# %%
#Define the callback to save the best model during the training
mc = ModelCheckpoint('best_model.hdf5', monitor='val_loss',verbose=1, save_best_only=True, mode='min')

# %%
# Train the model for 30 epochs with batch size of 32:
history=model.fit(x_tr, y_tr ,epochs=30, batch_size=32, validation_data=(x_val,y_val), callbacks=[mc])
# Out:
# Epoch 1/30
# 133/133 [==============================] - ETA: 0s - loss: 0.1875
# Epoch 1: val_loss improved from inf to 0.03611, saving model to best_model.hdf5
# 133/133 [==============================] - 28s 191ms/step - loss: 0.1875 - val_loss: 0.0361
# Epoch 2/30
#   1/133 [..............................] - ETA: 17s - loss: 0.0488
# C:\Users\rudra\anaconda3\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 133/133 [==============================] - ETA: 0s - loss: 0.0431
# Epoch 2: val_loss improved from 0.03611 to 0.02591, saving model to best_model.hdf5
# 133/133 [==============================] - 25s 189ms/step - loss: 0.0431 - val_loss: 0.0259
# Epoch 3/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0375
# Epoch 3: val_loss did not improve from 0.02591
# 133/133 [==============================] - 27s 204ms/step - loss: 0.0375 - val_loss: 0.0266
# Epoch 4/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0334
# Epoch 4: val_loss improved from 0.02591 to 0.02296, saving model to best_model.hdf5
# 133/133 [==============================] - 27s 203ms/step - loss: 0.0334 - val_loss: 0.0230
# Epoch 5/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0313
# Epoch 5: val_loss did not improve from 0.02296
# 133/133 [==============================] - 27s 205ms/step - loss: 0.0313 - val_loss: 0.0277
# Epoch 6/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0301
# Epoch 6: val_loss did not improve from 0.02296
# 133/133 [==============================] - 26s 199ms/step - loss: 0.0301 - val_loss: 0.0254
# Epoch 7/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0281
# Epoch 7: val_loss improved from 0.02296 to 0.02254, saving model to best_model.hdf5
# 133/133 [==============================] - 24s 183ms/step - loss: 0.0281 - val_loss: 0.0225
# Epoch 8/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0270
# Epoch 8: val_loss did not improve from 0.02254
# 133/133 [==============================] - 23s 172ms/step - loss: 0.0270 - val_loss: 0.0272
# Epoch 9/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0269
# Epoch 9: val_loss did not improve from 0.02254
# 133/133 [==============================] - 26s 195ms/step - loss: 0.0269 - val_loss: 0.0235
# Epoch 10/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0280
# Epoch 10: val_loss did not improve from 0.02254
# 133/133 [==============================] - 24s 179ms/step - loss: 0.0280 - val_loss: 0.0232
# Epoch 11/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0248
# Epoch 11: val_loss improved from 0.02254 to 0.02249, saving model to best_model.hdf5
# 133/133 [==============================] - 24s 181ms/step - loss: 0.0248 - val_loss: 0.0225
# Epoch 12/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0217
# Epoch 12: val_loss improved from 0.02249 to 0.02006, saving model to best_model.hdf5
# 133/133 [==============================] - 24s 180ms/step - loss: 0.0217 - val_loss: 0.0201
# Epoch 13/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0208
# Epoch 13: val_loss did not improve from 0.02006
# 133/133 [==============================] - 22s 164ms/step - loss: 0.0208 - val_loss: 0.0236
# Epoch 14/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0202
# Epoch 14: val_loss improved from 0.02006 to 0.01955, saving model to best_model.hdf5
# 133/133 [==============================] - 23s 173ms/step - loss: 0.0202 - val_loss: 0.0196
# Epoch 15/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0184
# Epoch 15: val_loss did not improve from 0.01955
# 133/133 [==============================] - 22s 166ms/step - loss: 0.0184 - val_loss: 0.0208
# Epoch 16/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0170
# Epoch 16: val_loss improved from 0.01955 to 0.01582, saving model to best_model.hdf5
# 133/133 [==============================] - 22s 168ms/step - loss: 0.0170 - val_loss: 0.0158
# Epoch 17/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0180
# Epoch 17: val_loss did not improve from 0.01582
# 133/133 [==============================] - 20s 154ms/step - loss: 0.0180 - val_loss: 0.0220
# Epoch 18/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0170
# Epoch 18: val_loss did not improve from 0.01582
# 133/133 [==============================] - 21s 158ms/step - loss: 0.0170 - val_loss: 0.0176
# Epoch 19/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0173
# Epoch 19: val_loss did not improve from 0.01582
# 133/133 [==============================] - 22s 163ms/step - loss: 0.0173 - val_loss: 0.0170
# Epoch 20/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0163
# Epoch 20: val_loss did not improve from 0.01582
# 133/133 [==============================] - 21s 158ms/step - loss: 0.0163 - val_loss: 0.0161
# Epoch 21/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0164
# Epoch 21: val_loss did not improve from 0.01582
# 133/133 [==============================] - 21s 159ms/step - loss: 0.0164 - val_loss: 0.0177
# Epoch 22/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0158
# Epoch 22: val_loss did not improve from 0.01582
# 133/133 [==============================] - 21s 159ms/step - loss: 0.0158 - val_loss: 0.0203
# Epoch 23/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0153
# Epoch 23: val_loss improved from 0.01582 to 0.01555, saving model to best_model.hdf5
# 133/133 [==============================] - 23s 172ms/step - loss: 0.0153 - val_loss: 0.0155
# Epoch 24/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0157
# Epoch 24: val_loss did not improve from 0.01555
# 133/133 [==============================] - 22s 166ms/step - loss: 0.0157 - val_loss: 0.0182
# Epoch 25/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0160
# Epoch 25: val_loss improved from 0.01555 to 0.01534, saving model to best_model.hdf5
# 133/133 [==============================] - 21s 162ms/step - loss: 0.0160 - val_loss: 0.0153
# Epoch 26/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0166
# Epoch 26: val_loss did not improve from 0.01534
# 133/133 [==============================] - 22s 162ms/step - loss: 0.0166 - val_loss: 0.0199
# Epoch 27/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0152
# Epoch 27: val_loss did not improve from 0.01534
# 133/133 [==============================] - 21s 155ms/step - loss: 0.0152 - val_loss: 0.0168
# Epoch 28/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0155
# Epoch 28: val_loss did not improve from 0.01534
# 133/133 [==============================] - 21s 162ms/step - loss: 0.0155 - val_loss: 0.0220
# Epoch 29/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0152
# Epoch 29: val_loss did not improve from 0.01534
# 133/133 [==============================] - 23s 171ms/step - loss: 0.0152 - val_loss: 0.0194
# Epoch 30/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0157
# Epoch 30: val_loss did not improve from 0.01534
# 133/133 [==============================] - 25s 187ms/step - loss: 0.0157 - val_loss: 0.0177

# %%
model.load_weights('best_model.hdf5')

# %%
#moving on to the evaluation part 
mse = model.evaluate(x_val,y_val)
print("Mean Square Error:",mse)
# Out:
# 15/15 [==============================] - 1s 67ms/step - loss: 0.0153
# Mean Square Error: 0.01534359809011221

# %%
# building a simple moving average model
def compute_moving_average(data):
  pred=[]
  for i in data:
    avg=np.sum(i)/len(i)
    pred.append(avg)
  return np.array(pred)

# %%
# reshaping the data
x_reshaped = x_val.reshape(-1,168)

# %%
# get predictions
y_pred = compute_moving_average(x_reshaped)

# %%
# evaluating the performance of model on the validation data
mse = np.sum ( (y_val - y_pred) **2 ) / (len(y_val))
print("Mean square of error:- ",mse)
# Out:
# Mean square of error:-  0.5546025834434455

# %%
def forecast(x_val, no_of_pred, ind):
  predictions=[]
  #intialize the array with a weeks data
  temp=x_val[ind]
  for i in range(no_of_pred):
    #predict for the next hour
    pred=model.predict(temp.reshape(1,-1,1))[0][0]
    
    #append the prediction as the last element of array
    temp = np.insert(temp,len(temp),pred)
    predictions.append(pred)
    #ignore the first element of array
    temp = temp[1:]
  return predictions

# %%
def forecast(x_val, no_of_pred, ind):
  predictions=[]
  #intialize the array with a weeks data
  temp=x_val[ind]
  for i in range(no_of_pred):
    #predict for the next hour
    pred=model.predict(temp.reshape(1,-1,1))[0][0]
    
    #append the prediction as the last element of array
    temp = np.insert(temp,len(temp),pred)
    predictions.append(pred)
    #ignore the first element of array
    temp = temp[1:]
  return predictions

# %%
#It’s time to forecast the traffic for the next 24 hours based on the previous week data.

no_of_pred =24
ind=72
y_pred= forecast(x_val,no_of_pred,ind)
y_true = y_val[ind:ind+(no_of_pred)]
# Out:
# 1/1 [==============================] - 1s 500ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 72ms/step

# %%
#Now plotting of real vs forecast values.

def plot(y_true,y_pred):
  ar = np.arange(len(y_true))
  plt.figure(figsize=(22,10))
  plt.plot(ar, y_true,'r')
  plt.plot(ar, y_pred,'y')
  plt.show()
plot(y_true,y_pred)
